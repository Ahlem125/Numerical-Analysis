# %% [markdown]
# # TP2 Interpolation Numérique
# <img src="tp2an.png">

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# On considère le programme MATLAB suivant :
# ``` octave
# function u=prog(x,y,c)
# S = y;
# n = length(x);
# for j=1:n
#     L = c-x;
#     for k=1:n
#         if (k == j)
#            L(k) = 1;
#         else
#            L(k) = L(k)/(x(j) - x(k));
#         end
#     end
#     S(j) = S(j)*prod(L);
# end
# u=sum(S);
# ```

# %% [markdown]
# ## Version Python

# %%
from numpy import prod
def prog(x,y,c):
    S = [] #tableau vide 
    n = len(x) #length de x
    
    for j in range(n):
        L =[c-xx for xx in x] #base de lagrange
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])    #l[k]=x-xk/xj-xk
        S.append(y[j]*prod(L)) # S polynome de lagrange  somme f(xi)*lxi(x)(produit)
        
    return  sum(S)

# %%
X=[1 ,2 ,3 ,4,-2];
Y=[-1, 0, 2 ,1,3];
for i in X:
    print(prog(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 3.0
# 8

# %%
import matplotlib.pyplot as plt
import numpy as np 

X=[1 ,2 ,3 ,4];
Y=[-1, 3, 2 ,1];
t=np.linspace(1,4,201) #intervalle de 1 a 4 et 201 valeur 
t
len(t)
imaget=[prog(X,Y,i) for i in t] #dessiner le polynome de lagrange 
plt.plot(t,imaget,'r')
plt.plot(X,Y,'ob')
plt.grid(True)
plt.show()

# %% [markdown]
# **Polynome d'interpolation de Lagrange**
# > Soient $(x_0,y_0), \ldots,(x_k,y_k),\ldots ,(x_n,k_n)$ $n+1$ points deux à deux distincts, le polynôme d'interpolation de Lagrange associés à ces points supports est défini par :
# > $$P_n(x)=\sum_{k=0}^{n-1} y_kL_k(x)$$
#
# avec $L_{0}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{n})}{(x_0-x_1)(x_0-x_2)\ldots(x_0-x_{n})}$ et $L_{k}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{k-1})(x-x_{k+1})\ldots(x_0-x_{n})}{(x_k-x_0)(x_k-x_1)\ldots(x_k-x_{k-1})(x_k-x_{k+1})\ldots(x_k-x_{n})}$ pour $k\in \{1,\ldots,n\}$

# %% [markdown]
# 1) Que renvoie la fonction PR lorsqu'on lui déclare  **x=(x(1),x(2),...,x(n))x=(x(1),x(2),...,x(n))**  et  **y=(y(1),y(2),...,y(n))y=(y(1),y(2),...,y(n))**  deux vecteurs de même longueur  `n` et `c`  un nombre réel donné.

# %% [markdown]
# ## Code python

# %%
from numpy import prod
def PR (x,y,c):
    S=[]
    n=len(x)
    for j in range(n):
        l=[c-h for h in x]
        for k in range (n):
            if k==j:
                l[k]=1
            else:
                 l[k]=l[k]/(x[j]-x[k])
        S.append(y[j]*prod(l))
    return sum(S)

# %%
X=[1,2,3,4]
Y=[-1,0,2,1]
c=3
print(PR(X,Y,c))
# Out:
# 2.0

# %%
X=[1,2,3,4]
Y=[-1,0,2,1]
for i in X :
    print (PR(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 10

# %% [markdown]
# 2) Que contient le vecteur  LL  après la fin de la boucle  kk .

# %%
def pr(x,y,c):
    S = [] 
    n = len(x)
    for c in x:
            for j in range(n):
                L =[c-xx for xx in x]
                for k in range(n):
                    if (k == j):                
                        L[k] = 1
                    else:
                        L[k] = L[k]/(x[j] - x[k])   
                S.append(y[j]*prod(L))

            return L[3]

# %%
X=[1,2,3,4]
Y=[-1,0,2,1]
for i in X:
    print(pr(X,Y,i))
# Out:
# 1
# 1
# 1
# 1

# %% [markdown]
# 3) Utiliser cette fonction pour dessiner le graph du polynôme de Lagrange  de la fonction $f(x) = \dfrac{1}{1 + x^2}$ aux points $x=[-1:0.1:1]$.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(-1,1,0.1)
f=lambda x:1/(1+x**2)
t=np.linspace(-1,1,100)
y=f(x)
imaget=[prog(x,y,i) for i in t] 
plt.plot(t,f(t),'r',x,y,'bo')
plt.grid(True)
plt.title("polynome de lagrange dans [-1:0.1:1]")
plt.xlabel ("x")
plt.ylabel ("f(x)")
plt.show()

# %% [markdown]
# ## conclusion
# L'un des défauts de la méthode de lagrange c'est qu'on doit reprondre tout le travail  lorsqu'on ajoute un nouveau point x_k avec k=n+1 , ce qui nécessite du temps a faire . Pour cela on a recours a la méthode de newton ou des differences divisées.

# %% [markdown]
# 4) On considère la fonction $F$ suivante :
# $$
# F(h) = \pi -\cos \left(\frac{h}{2}\right) + h \sqrt{1-\left(\frac{h}{2}\right)^2}, \qquad
# h\in [0,2],
# $$
# et les points d'interpolation $x_i = ih$, $0\leq i\leq n$, avec $ n=20$ et $h=0.1$.

# %% [markdown]
# 4.1) Représenter sur un même graphe la fonction $F$ et $p_n$, où
#  $p_n$ est le polynôme d'interpolation de Lagrange de $F$ aux
#  points $x_0,\,\ldots,\,x_n$.

# %%
import math
x=np.arange(0,3)
p=[]
f= lambda x:math.pi-math.cos(x/2)+x*math.sqrt(1-(x/2)**2)
f1 = np.vectorize(f)
y=f1(x)
t=np.linspace(-1,1,100)
for i in range(len(t)):
    p.append(PR(x,y,t[i]))
plt.plot(t,p,"r",x,y,"b*",t,f1(t),"g")
plt.title("la fonction F et pn")
plt.xlabel ("x")
plt.ylabel ("f(x)")
plt.show()    

#numpy.vectorize permet de convertir des fonctions «ordinaires»
# qui attendent un seul nombre en entrée en une fonction 
#qui peut également convertir une liste d'entrées en une liste dans laquelle la fonction a été mappée sur chaque entrée.

# %% [markdown]
# 2)Tracer la courbe d'erreur  (la
#  fonction $F-p_n$). Qu'observer vous.

# %%
import math
x=np.arange(0,3)
p=[]
f= lambda x:math.pi-math.cos(x/2)+x*math.sqrt(1-(x/2)**2)
f1 = np.vectorize(f)
y=f1(x)
t=np.linspace(-1,1,100)
for i in range(len(t)):
    p.append(PR(x,y,t[i]))
plt.title("la courbe d'erreur de la fonction F")
plt.plot(t,f1(t)-p,'r') 
plt.show()

# %% [markdown]
# ## Exercice 2  ( Phenomène de Runge )

# %% [markdown]
# 1) Vérifier que sur $[-5,5]$ le polynôme d'interpolation de Lagrange
#   de la fonction $f$ définie par $f(x)=\displaystyle{\frac{1}{1+x^2}}$,
# en $N$ points uniformément espacés ne convergent pas correctement aux voisinages de $-1$ et $1$, pour $N=7,8,9,10 ...$

# %% [raw]
#  > polyfit =Il s'agit d'une fonction d'ajustement polynomiale des moindres carrés assez générale qui accepte l'ensemble de données et une fonction polynomiale de n'importe quel degré (spécifié par l'utilisateur) et renvoie un tableau de coefficients qui minimise l'erreur quadratique
#
# La méthode polyval(p, x) évalue un polynôme à des valeurs spécifiques. Paramètres : p : [array_like ou poly1D] les coefficients polynomiaux sont donnés par ordre décroissant de puissances. Si le deuxième paramètre (racine) est défini sur True, les valeurs du tableau sont les racines de l'équation polynomiale.

# %%
import numpy as np
import matplotlib.pyplot as plt
N=7
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation avec N=7")
##############################
N=8
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation  avec N=8")
##############################
N=9
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("In N=9")
##############################
N=10;
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("In N=10")
# Out:
# Text(0.5, 1.0, 'In N=10')

# %%
import numpy as np
import matplotlib.pyplot as plt
N=7
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation avec N=7")
##############################
N=8
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation  avec N=8")
##############################
N=9
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("In N=9")
##############################
N=10;
X=np.linspace(-5,5,N)
f=  lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("In N=10")
plt.subplots_adjust(left=0.130,
                    bottom=0.2, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.80)

# %% [markdown]
# ## Remarque:
#
# On remarque que le polynôme d'interpolation de Lagrange de la fonction f ne convergent pas correctement aux voisinages de -1 et 1 aux differents points d'itérations.

# %% [markdown]
# 2) Les points de Tchebycheff sur un intervalle $[a;b]$ sont définie par :
#   $$x_k=\dfrac{a+b}{2}+\dfrac{a-b}{2}\cos\left(\frac{k-1}{n-1}\pi\right)\hspace{0.5cm} (k=1,..,n: x_1=a:x_n=b)$$
#
#   Vérifier que sur $[-5; 5]$ ; l'interpolation polynômiale de $f(x) = \dfrac{1}{1 + x^2}$ ; en $N$ points de Tchebychev
# est meilleure qu'une  interpolation utilisant $N$ points uniforment espacés (on prendra $N=10, 11, 16, 17$).

# %%
import math
def tcheb(a,b,n):
    v=[]
    for k in range(n):
        v.append((a+b)/2+(a-b)/2*math.cos((k-1)/(n-1)*math.pi))
    return v

# %%
tcheb(-5,5,11)
# Out:
# [-4.755282581475767,
#  -5.0,
#  -4.755282581475767,
#  -4.045084971874737,
#  -2.938926261462366,
#  -1.5450849718747373,
#  -3.061616997868383e-16,
#  1.5450849718747368,
#  2.938926261462365,
#  4.045084971874736,
#  4.755282581475767]

# %%
import numpy as np
import matplotlib.pyplot as plt
N=10
t=np.linspace(-5,5,1000)
f= lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[]
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t,np.polyval(pt,t),'g')
plt.title("Tchebycheff N=10")
# Out:
# C:\Users\Ahlem\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Tchebycheff N=10')

# %%
N=11
t=np.linspace(-5,5,1000)
f= lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[]
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1);
plt.plot(t,f(t),'r',Xt,Yt,'ob',t,np.polyval(pt,t),'g')
plt.title("Tchebycheff N=11")
# Out:
# C:\Users\Ahlem\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Tchebycheff N=11')

# %%
import numpy as np
import matplotlib.pyplot as plt
N=16
t=np.linspace(-5,5,1000)
f= lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[]
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1);
plt.plot(t,f(t),'r',Xt,Yt,'ob',t,np.polyval(pt,t),'g')
plt.title("Tchebycheff N=16")
# Out:
# C:\Users\Ahlem\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Tchebycheff N=16')

# %%
N=17
t=np.linspace(-5,5,1000)
f= lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[]
for i in Xt:
    Yt.append(f(i))
pt=np.polyfit(Xt,Yt,N-1)
plt.plot(t,f(t),'r',Xt,Yt,'ob',t,np.polyval(pt,t),'g')
plt.title("Tchebycheff N=17")
# Out:
# C:\Users\Ahlem\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Tchebycheff N=17')

# %% [markdown]
# ## Remarque:
#
# Le phenomene de Runge peut etre considerablement attenue en choisissant judicieusement les points d’´evaluation. En particulier, on peut d´emontrer qu’en choisissant les racines des polynomes de Chebyshev (Tchebychev) comme points d’´evaluation, on minimise les ecarts entre la fonction interpolee et le polynome d’interpolation. On remarque que lee phénomène de non-convergence des polynômes d'interpolation converge vers la fonction le phénomène de Runge.

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# On considère les deux programme MATLAB suivant :
# ``` octave
# function f=intN(x,f)% RECURSIVE
# m=length(x);
# for k=2:m;
#     f(k:m)=(f(k:m)-f(k-1:m-1))./(x(k:m)-x(1:m+1-k))
# end
# ```
# ``` octave
# function p=intNval(x,c,t)
# m=length(x);
# p=c(m)*ones(size(t));
# for k=m-1:-1:1;
#     p=p.*(t-x(k))+c(k);
# end
# ```

# %% [markdown]
# 1) Déterminer en utilisant les deux codes puis par un calcul à la main le polynôme de Newton pour les données suivantes :
#
#
# <center>
# <table>
#       $\begin{array}{|c|c|c|}
#    \hline
#    i & x_i  & y_i \\
#    \hline
#    0 &   -1  &   6 \\
#    1 &   0 &  1 \\
#    2 &  2  &  3 \\
#    3 &  5  &  66 \\
#    \hline
# \end{array}$
# </table>
# </center>

# %%
def intN(x,y):
    m=len(x)
    f=np.zeros(m)
    for k in range(1,m):
        f[k:m+1]=np.array(np.array(y[k:m+1])-np.array(y[k-1:m-1]))/np.array(np.array(x[k:m+1])-np.array(x[0:m-k]))
    return f

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
intN(x,y)
# Out:
# array([ 0.        , -5.        ,  0.66666667, 10.5       ])

# %%
def intNval(x,y,t):
    m=len(x)
    p=y[m-1]*np.ones(len(t))
    for k in range(m-2,-1,-1):
        p=p*np.array((np.array(t)-x[k]))+y[k]
    return p

# %%
x=[-1,0,2,5];
y=[6,1,3,66];
t=[0,1,2,3];
intNval(x,y,t)
# Out:
# array([   7., -118.,   27.,  838.])

# %%
##Calcul a la main

# %% [markdown]
# 2) Donner le Graph du polynôme trouvé en 1) dans l'intervalle $[-1;5]$.

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
f=intN(x,y)
plt.plot(x,f,'r',x,y,'ob')
plt.show()

# %% [markdown]
# 3) Calculer $P(1)$ en utilisant le polynôme trouvé en 1).

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
p=intNval(x,y,t)
p[0]
# Out:
# 7.0

# %% [markdown]
# ## Conclusion génerale
# la méthode de Newton est, dans son application la plus simple, un algorithme efficace pour trouver numériquement une approximation précise d'un zéro (ou racine) d'une fonction réelle d'une variable réelle.
#
# La méthode de Newton est probablement l’une des méthodes les plus utilisées en calcul numérique. Ces intérêts sont très nombreux. On peut par exemple l’utiliser pour trouver des optimums locaux (dans le cas des racines d’une dérivée) ou pour approcher des nombres comme $\sqrt{2}$ qui n’ont pas de représentation numérique exacte en machine.
